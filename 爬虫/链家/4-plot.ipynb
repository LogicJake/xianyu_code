# %% [markdown]
# # 1.数据基本情况

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('house_bj.csv')

# %%
data.head()
# Out:
#    所在区     小区名称    户型  面积(平米)  朝向  装修       所在楼层   建造年份 所在位置  总价(万元)  \
# 0  东城区    法华南里   2室1厅   80.85  南北  精装   高楼层(共6层)  1993年  崇文门     865
# 1  东城区   和平里一区   2室1厅   39.46  南北  精装   底层(共11层)  1990年  和平里     595
# 2  东城区  新景家园西区   2室1厅   73.85  南北  精装  中楼层(共18层)  2004年  崇文门     935
# 3  东城区  和平新城一期   2室2厅  132.32   东  简装  高楼层(共21层)  2003年  和平里    1350
# 4  东城区   金鱼池西区   4室2厅  149.92  西北  简装   中楼层(共7层)  2002年   天坛    1030
#
#    单价(元/平米) 有无电梯
# 0    106989  无电梯
# 1    150786  有电梯
# 2    126608  有电梯
# 3    102026  有电梯
# 4     68704  无电梯

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8418 entries, 0 to 8417
# Data columns (total 12 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   所在区       8418 non-null   object
#  1   小区名称      8418 non-null   object
#  2   户型        8418 non-null   object
#  3   面积(平米)    8418 non-null   float64
#  4   朝向        8418 non-null   object
#  5   装修        8418 non-null   object
#  6   所在楼层      8418 non-null   object
#  7   建造年份      8418 non-null   object
#  8   所在位置      8418 non-null   object
#  9   总价(万元)    8418 non-null   int64
#  10  单价(元/平米)  8418 non-null   int64
#  11  有无电梯      8418 non-null   object
# dtypes: float64(1), int64(2), object(9)
# memory usage: 789.3+ KB

# %%
data.describe()
# Out:
#             面积(平米)       总价(万元)       单价(元/平米)
# count  8418.000000  8418.000000    8418.000000
# mean     96.135518   583.014136   63268.518651
# std      54.361255   438.039566   33389.204880
# min      16.300000    51.000000    9916.000000
# 25%      63.230000   312.000000   39745.000000
# 50%      85.335000   468.000000   51897.500000
# 75%     107.937500   699.000000   78889.000000
# max     768.790000  6000.000000  179932.000000

# %% [markdown]
# # 2.房价影响因素可视化分析

# %% [markdown]
# ## （1）所在区对房价的影响

# %%
from pyecharts import Bar, Line, Overlap

zone_price = pd.merge(
    data.groupby(['所在区'])['单价(元/平米)'].mean().round(0).sort_values(
        ascending=False).to_frame().reset_index(),
    data.groupby(['所在区'])['总价(万元)'].mean().round(0).to_frame().reset_index(),
    on=['所在区'])
bar = Bar("北京各区二手房价格")
bar.add(
    "单价(元/平米)",
    zone_price['所在区'],
    zone_price['单价(元/平米)'],
    is_label_show=True,
    label_pos='inside',
    label_text_color='#000',
    is_toolbox_show=False,
)
line = Line()
line.add(
    "总价(万元)",
    zone_price['所在区'],
    zone_price['总价(万元)'],
    is_label_show=True,
    is_toolbox_show=False,
)

overlap = Overlap(height=400, width=900)
overlap.add(bar)
overlap.add(
    line,
    yaxis_index=1,
    is_add_yaxis=True,
)
overlap
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="ec06725dda534e518d7b7fce9714cc96" style="width:900px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_ec06725dda534e518d7b7fce9714cc96 = echarts.init(document.getElementById('ec06725dda534e518d7b7fce9714cc96'), 'light', {renderer: 'canvas'});
#
# var option_ec06725dda534e518d7b7fce9714cc96 = {
#     "title": [
#         {
#             "text": "\u5317\u4eac\u5404\u533a\u4e8c\u624b\u623f\u4ef7\u683c",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "series_id": 2575174,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u5355\u4ef7(\u5143/\u5e73\u7c73)",
#             "data": [
#                 129975.0,
#                 104509.0,
#                 97379.0,
#                 71804.0,
#                 61590.0,
#                 52835.0,
#                 47639.0,
#                 44196.0,
#                 43533.0,
#                 37868.0,
#                 31061.0
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "normal": {
#                     "show": true,
#                     "position": "inside",
#                     "textStyle": {
#                         "color": "#000",
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "markLine": {
#                 "data": []
#             },
#             "seriesId": 2575174
#         },
#         {
#             "type": "line",
#             "name": "\u603b\u4ef7(\u4e07\u5143)",
#             "symbol": "emptyCircle",
#             "symbolSize": 4,
#             "smooth": false,
#             "step": false,
#             "showSymbol": true,
#             "data": [
#                 918.0,
#                 987.0,
#                 878.0,
#                 732.0,
#                 536.0,
#                 405.0,
#                 485.0,
#                 432.0,
#                 415.0,
#                 529.0,
#                 319.0
#             ],
#             "label": {
#                 "normal": {
#                     "show": true,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "lineStyle": {
#                 "normal": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "markLine": {
#                 "data": []
#             },
#             "seriesId": 2575174,
#             "xAxisIndex": 0,
#             "yAxisIndex": 1
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5355\u4ef7(\u5143/\u5e73\u7c73)",
#                 "\u603b\u4ef7(\u4e07\u5143)"
#             ],
#             "selectedMode": "multiple",
#             "show": true,
#             "left": "center",
#             "top": "top",
#             "orient": "horizontal",
#             "textStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "xAxis": [
#         {
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "boundaryGap": true,
#             "type": "category",
#             "splitLine": {
#                 "show": false
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "rotate": 0,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 12
#                 }
#             },
#             "data": [
#                 "\u897f\u57ce\u533a",
#                 "\u4e1c\u57ce\u533a",
#                 "\u6d77\u6dc0\u533a",
#                 "\u671d\u9633\u533a",
#                 "\u4e30\u53f0\u533a",
#                 "\u77f3\u666f\u5c71\u533a",
#                 "\u660c\u5e73\u533a",
#                 "\u5927\u5174\u533a",
#                 "\u901a\u5dde\u533a",
#                 "\u987a\u4e49\u533a",
#                 "\u623f\u5c71\u533a"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "boundaryGap": true,
#             "type": "value",
#             "splitLine": {
#                 "show": true
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "formatter": "{value} ",
#                 "rotate": 0,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 12
#                 }
#             }
#         },
#         {
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "boundaryGap": true,
#             "type": "value",
#             "splitLine": {
#                 "show": true
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "formatter": "{value} ",
#                 "rotate": 0,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 12
#                 }
#             }
#         }
#     ],
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ]
# };
# myChart_ec06725dda534e518d7b7fce9714cc96.setOption(option_ec06725dda534e518d7b7fce9714cc96);
#
#     });
# </script>

# %% [markdown]
# ## （2）户型对房价的影响

# %%
#分析户型与二手房价格
from pyecharts import Pie, Bar

layout_price = pd.merge(data.groupby(
    ['户型'])['单价(元/平米)'].mean().round(0).sort_values(
        ascending=False).to_frame().reset_index(),
                        data.groupby(['户型']).size().to_frame().reset_index(),
                        on='户型')
layout_price.columns = ['户型', '单价(元/平米)', '计数']
print(layout_price)
#进行户型统计，发现存在‘3室0厅’和‘3室3厅’的户型，且数量较少，因此删除
layout_price = layout_price[(layout_price['户型'] != '3室0厅')
                            & (layout_price['户型'] != '3室3厅')]
print(layout_price)
# Out:
#        户型  单价(元/平米)    计数
# 0    8室3厅   94778.0     1
# 1    2室0厅   93201.0    13
# 2    3室0厅   92571.0    10
# 3    6室4厅   91293.0     1
# 4    3室3厅   88700.0     7
# 5    2室3厅   86689.0     1
# 6    1室0厅   72720.0   152
# 7    1室1厅   71084.0  1017
# 8    4室4厅   69293.0     2
# 9    4室3厅   66413.0    24
# 10   3室1厅   65276.0  1337
# 11   8室2厅   64754.0     2
# 12   2室1厅   64028.0  3790
# 13   7室5厅   62436.0     1
# 14   4室1厅   60186.0   106
# 15   1室2厅   58903.0    13
# 16   4室2厅   58161.0   285
# 17   3室2厅   57314.0   847
# 18   2室2厅   56801.0   520
# 19   5室1厅   51902.0    16
# 20   5室5厅   51719.0     1
# 21   8室4厅   51038.0     1
# 22   5室2厅   50855.0   114
# 23   6室3厅   50150.0    17
# 24   5室3厅   47182.0    25
# 25   6室2厅   44962.0    29
# 26   9室1厅   41916.0     1
# 27   7室3厅   39085.0     5
# 28   8室6厅   37401.0     1
# 29  2房间2卫   36944.0     6
# 30   5室4厅   35930.0     3
# 31   5室0厅   35765.0     2
# 32   6室1厅   34677.0     4
# 33  12室2厅   34167.0     1
# 34   7室2厅   33310.0     4
# 35  3房间2卫   31897.0     3
# 36  3房间1卫   28097.0    13
# 37  5房间2卫   26331.0     3
# 38  2房间1卫   26053.0    23
# 39  4房间2卫   24899.0     1
# 40  4房间1卫   22204.0     1
# 41  3房间0卫   21535.0     1
# 42  1房间1卫   21433.0    13
# 43  5房间1卫   16768.0     1
#        户型  单价(元/平米)    计数
# 0    8室3厅   94778.0     1
# 1    2室0厅   93201.0    13
# 3    6室4厅   91293.0     1
# 5    2室3厅   86689.0     1
# 6    1室0厅   72720.0   152
# 7    1室1厅   71084.0  1017
# 8    4室4厅   69293.0     2
# 9    4室3厅   66413.0    24
# 10   3室1厅   65276.0  1337
# 11   8室2厅   64754.0     2
# 12   2室1厅   64028.0  3790
# 13   7室5厅   62436.0     1
# 14   4室1厅   60186.0   106
# 15   1室2厅   58903.0    13
# 16   4室2厅   58161.0   285
# 17   3室2厅   57314.0   847
# 18   2室2厅   56801.0   520
# 19   5室1厅   51902.0    16
# 20   5室5厅   51719.0     1
# 21   8室4厅   51038.0     1
# 22   5室2厅   50855.0   114
# 23   6室3厅   50150.0    17
# 24   5室3厅   47182.0    25
# 25   6室2厅   44962.0    29
# 26   9室1厅   41916.0     1
# 27   7室3厅   39085.0     5
# 28   8室6厅   37401.0     1
# 29  2房间2卫   36944.0     6
# 30   5室4厅   35930.0     3
# 31   5室0厅   35765.0     2
# 32   6室1厅   34677.0     4
# 33  12室2厅   34167.0     1
# 34   7室2厅   33310.0     4
# 35  3房间2卫   31897.0     3
# 36  3房间1卫   28097.0    13
# 37  5房间2卫   26331.0     3
# 38  2房间1卫   26053.0    23
# 39  4房间2卫   24899.0     1
# 40  4房间1卫   22204.0     1
# 41  3房间0卫   21535.0     1
# 42  1房间1卫   21433.0    13
# 43  5房间1卫   16768.0     1

# %%
pie = Pie(
    "北京二手房各户型房源数量统计",
    width=700,
    height=400,
)
pie.add("",
        layout_price['户型'],
        layout_price['计数'],
        is_label_show=True,
        legend_orient="vertical",
        legend_pos="right",
        is_toolbox_show=False,
        label_formatter='{b}:{c},{d}%')
pie
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="ddb5b20fd88c4175b4ccaef30abaa33f" style="width:700px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_ddb5b20fd88c4175b4ccaef30abaa33f = echarts.init(document.getElementById('ddb5b20fd88c4175b4ccaef30abaa33f'), 'light', {renderer: 'canvas'});
#
# var option_ddb5b20fd88c4175b4ccaef30abaa33f = {
#     "title": [
#         {
#             "text": "\u5317\u4eac\u4e8c\u624b\u623f\u5404\u6237\u578b\u623f\u6e90\u6570\u91cf\u7edf\u8ba1",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "series_id": 6251879,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "pie",
#             "data": [
#                 {
#                     "name": "8\u5ba43\u5385",
#                     "value": 1
#                 },
#                 {
#                     "name": "2\u5ba40\u5385",
#                     "value": 13
#                 },
#                 {
#                     "name": "6\u5ba44\u5385",
#                     "value": 1
#                 },
#                 {
#                     "name": "2\u5ba43\u5385",
#                     "value": 1
#                 },
#                 {
#                     "name": "1\u5ba40\u5385",
#                     "value": 152
#                 },
#                 {
#                     "name": "1\u5ba41\u5385",
#                     "value": 1017
#                 },
#                 {
#                     "name": "4\u5ba44\u5385",
#                     "value": 2
#                 },
#                 {
#                     "name": "4\u5ba43\u5385",
#                     "value": 24
#                 },
#                 {
#                     "name": "3\u5ba41\u5385",
#                     "value": 1337
#                 },
#                 {
#                     "name": "8\u5ba42\u5385",
#                     "value": 2
#                 },
#                 {
#                     "name": "2\u5ba41\u5385",
#                     "value": 3790
#                 },
#                 {
#                     "name": "7\u5ba45\u5385",
#                     "value": 1
#                 },
#                 {
#                     "name": "4\u5ba41\u5385",
#                     "value": 106
#                 },
#                 {
#                     "name": "1\u5ba42\u5385",
#                     "value": 13
#                 },
#                 {
#                     "name": "4\u5ba42\u5385",
#                     "value": 285
#                 },
#                 {
#                     "name": "3\u5ba42\u5385",
#                     "value": 847
#                 },
#                 {
#                     "name": "2\u5ba42\u5385",
#                     "value": 520
#                 },
#                 {
#                     "name": "5\u5ba41\u5385",
#                     "value": 16
#                 },
#                 {
#                     "name": "5\u5ba45\u5385",
#                     "value": 1
#                 },
#                 {
#                     "name": "8\u5ba44\u5385",
#                     "value": 1
#                 },
#                 {
#                     "name": "5\u5ba42\u5385",
#                     "value": 114
#                 },
#                 {
#                     "name": "6\u5ba43\u5385",
#                     "value": 17
#                 },
#                 {
#                     "name": "5\u5ba43\u5385",
#                     "value": 25
#                 },
#                 {
#                     "name": "6\u5ba42\u5385",
#                     "value": 29
#                 },
#                 {
#                     "name": "9\u5ba41\u5385",
#                     "value": 1
#                 },
#                 {
#                     "name": "7\u5ba43\u5385",
#                     "value": 5
#                 },
#                 {
#                     "name": "8\u5ba46\u5385",
#                     "value": 1
#                 },
#                 {
#                     "name": "2\u623f\u95f42\u536b",
#                     "value": 6
#                 },
#                 {
#                     "name": "5\u5ba44\u5385",
#                     "value": 3
#                 },
#                 {
#                     "name": "5\u5ba40\u5385",
#                     "value": 2
#                 },
#                 {
#                     "name": "6\u5ba41\u5385",
#                     "value": 4
#                 },
#                 {
#                     "name": "12\u5ba42\u5385",
#                     "value": 1
#                 },
#                 {
#                     "name": "7\u5ba42\u5385",
#                     "value": 4
#                 },
#                 {
#                     "name": "3\u623f\u95f42\u536b",
#                     "value": 3
#                 },
#                 {
#                     "name": "3\u623f\u95f41\u536b",
#                     "value": 13
#                 },
#                 {
#                     "name": "5\u623f\u95f42\u536b",
#                     "value": 3
#                 },
#                 {
#                     "name": "2\u623f\u95f41\u536b",
#                     "value": 23
#                 },
#                 {
#                     "name": "4\u623f\u95f42\u536b",
#                     "value": 1
#                 },
#                 {
#                     "name": "4\u623f\u95f41\u536b",
#                     "value": 1
#                 },
#                 {
#                     "name": "3\u623f\u95f40\u536b",
#                     "value": 1
#                 },
#                 {
#                     "name": "1\u623f\u95f41\u536b",
#                     "value": 13
#                 },
#                 {
#                     "name": "5\u623f\u95f41\u536b",
#                     "value": 1
#                 }
#             ],
#             "radius": [
#                 "0%",
#                 "75%"
#             ],
#             "center": [
#                 "50%",
#                 "50%"
#             ],
#             "label": {
#                 "normal": {
#                     "show": true,
#                     "position": "outside",
#                     "textStyle": {
#                         "fontSize": 12
#                     },
#                     "formatter": "{b}:{c},{d}%"
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     },
#                     "formatter": "{b}: {d}%"
#                 }
#             },
#             "seriesId": 6251879
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "8\u5ba43\u5385",
#                 "2\u5ba40\u5385",
#                 "6\u5ba44\u5385",
#                 "2\u5ba43\u5385",
#                 "1\u5ba40\u5385",
#                 "1\u5ba41\u5385",
#                 "4\u5ba44\u5385",
#                 "4\u5ba43\u5385",
#                 "3\u5ba41\u5385",
#                 "8\u5ba42\u5385",
#                 "2\u5ba41\u5385",
#                 "7\u5ba45\u5385",
#                 "4\u5ba41\u5385",
#                 "1\u5ba42\u5385",
#                 "4\u5ba42\u5385",
#                 "3\u5ba42\u5385",
#                 "2\u5ba42\u5385",
#                 "5\u5ba41\u5385",
#                 "5\u5ba45\u5385",
#                 "8\u5ba44\u5385",
#                 "5\u5ba42\u5385",
#                 "6\u5ba43\u5385",
#                 "5\u5ba43\u5385",
#                 "6\u5ba42\u5385",
#                 "9\u5ba41\u5385",
#                 "7\u5ba43\u5385",
#                 "8\u5ba46\u5385",
#                 "2\u623f\u95f42\u536b",
#                 "5\u5ba44\u5385",
#                 "5\u5ba40\u5385",
#                 "6\u5b

# %%
bar = Bar("北京二手房各户型平均房价(元/平米)", width=600, height=400)
bar.add("",
        layout_price['户型'],
        layout_price['单价(元/平米)'],
        is_label_show=True,
        bar_category_gap='40%',
        is_toolbox_show=False)
bar
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="59b7ee7031e74946b3c3926ced3fad17" style="width:600px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_59b7ee7031e74946b3c3926ced3fad17 = echarts.init(document.getElementById('59b7ee7031e74946b3c3926ced3fad17'), 'light', {renderer: 'canvas'});
#
# var option_59b7ee7031e74946b3c3926ced3fad17 = {
#     "title": [
#         {
#             "text": "\u5317\u4eac\u4e8c\u624b\u623f\u5404\u6237\u578b\u5e73\u5747\u623f\u4ef7(\u5143/\u5e73\u7c73)",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "series_id": 8374630,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "bar",
#             "data": [
#                 94778.0,
#                 93201.0,
#                 91293.0,
#                 86689.0,
#                 72720.0,
#                 71084.0,
#                 69293.0,
#                 66413.0,
#                 65276.0,
#                 64754.0,
#                 64028.0,
#                 62436.0,
#                 60186.0,
#                 58903.0,
#                 58161.0,
#                 57314.0,
#                 56801.0,
#                 51902.0,
#                 51719.0,
#                 51038.0,
#                 50855.0,
#                 50150.0,
#                 47182.0,
#                 44962.0,
#                 41916.0,
#                 39085.0,
#                 37401.0,
#                 36944.0,
#                 35930.0,
#                 35765.0,
#                 34677.0,
#                 34167.0,
#                 33310.0,
#                 31897.0,
#                 28097.0,
#                 26331.0,
#                 26053.0,
#                 24899.0,
#                 22204.0,
#                 21535.0,
#                 21433.0,
#                 16768.0
#             ],
#             "barCategoryGap": "40%",
#             "label": {
#                 "normal": {
#                     "show": true,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "markLine": {
#                 "data": []
#             },
#             "seriesId": 8374630
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selectedMode": "multiple",
#             "show": true,
#             "left": "center",
#             "top": "top",
#             "orient": "horizontal",
#             "textStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "xAxis": [
#         {
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "boundaryGap": true,
#             "type": "category",
#             "splitLine": {
#                 "show": false
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "rotate": 0,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 12
#                 }
#             },
#             "data": [
#                 "8\u5ba43\u5385",
#                 "2\u5ba40\u5385",
#                 "6\u5ba44\u5385",
#                 "2\u5ba43\u5385",
#                 "1\u5ba40\u5385",
#                 "1\u5ba41\u5385",
#                 "4\u5ba44\u5385",
#                 "4\u5ba43\u5385",
#                 "3\u5ba41\u5385",
#                 "8\u5ba42\u5385",
#                 "2\u5ba41\u5385",
#                 "7\u5ba45\u5385",
#                 "4\u5ba41\u5385",
#                 "1\u5ba42\u5385",
#                 "4\u5ba42\u5385",
#                 "3\u5ba42\u5385",
#                 "2\u5ba42\u5385",
#                 "5\u5ba41\u5385",
#                 "5\u5ba45\u5385",
#                 "8\u5ba44\u5385",
#                 "5\u5ba42\u5385",
#                 "6\u5ba43\u5385",
#                 "5\u5ba43\u5385",
#                 "6\u5ba42\u5385",
#                 "9\u5ba41\u5385",
#                 "7\u5ba43\u5385",
#                 "8\u5ba46\u5385",
#                 "2\u623f\u95f42\u536b",
#                 "5\u5ba44\u5385",
#                 "5\u5ba40\u5385",
#                 "6\u5ba41\u5385",
#                 "12\u5ba42\u5385",
#                 "7\u5ba42\u5385",
#                 "3\u623f\u95f42\u536b",
#                 "3\u623f\u95f41\u536b",
#                 "5\u623f\u95f42\u536b",
#                 "2\u623f\u95f41\u536b",
#                 "4\u623f\u95f42\u536b",
#                 "4\u623f\u95f41\u536b",
#                 "3\u623f\u95f40\u536b",
#                 "1\u623f\u95f41\u536b",
#                 "5\u623f\u95f41\u536b"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "boundaryGap": true,
#             "type": "value",
#             "splitLine": {
#                 "show": true
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "formatter": "{value} ",
#                 "rotate": 0,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 12
#                 }
#             }
#         }
#     ],
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ]
# };
# myChart_59b7ee7031e74946b3c3926ced3fad17.setOption(option_59b7ee7031e74946b3c3926ced3fad17);
#
#     });
# </script>

# %% [markdown]
# ## （3）所在位置对房价的影响

# %%
##分析北京二手房位置和单价
from pyecharts import Bar
#print (data.ix[:,['小区名称','所在区']])
pos_perprice = data.groupby(['所在位置',
                             '所在区'])['单价(元/平米)'].mean().round(0).sort_values(
                                 ascending=False).to_frame().reset_index()
pos_perprice.columns = ['所在位置', '所在区', '单价(元/平米)']
top10_pos = pos_perprice.head(10).sort_values(
    ['单价(元/平米)'],
    ascending=True)  #.merge(data.ix[:,['小区名称','所在区']],on='小区名称',how = 'left')
top10_pos
# Out:
#   所在位置  所在区  单价(元/平米)
# 9   官园  西城区  142179.0
# 8   西单  西城区  143914.0
# 7   万柳  海淀区  144334.0
# 6   月坛  西城区  145453.0
# 5   马甸  西城区  152459.0
# 4  德胜门  西城区  154319.0
# 3  六铺炕  西城区  155015.0
# 2  交道口  东城区  156073.0
# 1  金融街  西城区  156687.0
# 0   西四  西城区  158446.0

# %%
bar = Bar('北京二手房平均单价TOP10位置(元/平米)', width=500)
bar.add('',
        top10_pos['所在位置'],
        top10_pos['单价(元/平米)'],
        is_label_show=True,
        label_text_color='#000',
        label_pos='inside',
        label_formatter='{b}:{c}',
        is_yaxis_show=False,
        is_convert=True)
bar
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="ce07283ac51a409888865fc8c53be047" style="width:500px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_ce07283ac51a409888865fc8c53be047 = echarts.init(document.getElementById('ce07283ac51a409888865fc8c53be047'), 'light', {renderer: 'canvas'});
#
# var option_ce07283ac51a409888865fc8c53be047 = {
#     "title": [
#         {
#             "text": "\u5317\u4eac\u4e8c\u624b\u623f\u5e73\u5747\u5355\u4ef7TOP10\u4f4d\u7f6e(\u5143/\u5e73\u7c73)",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "\u4e0b\u8f7d\u56fe\u7247"
#             },
#             "restore": {
#                 "show": true
#             },
#             "dataView": {
#                 "show": true
#             }
#         }
#     },
#     "series_id": 604426,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "bar",
#             "data": [
#                 142179.0,
#                 143914.0,
#                 144334.0,
#                 145453.0,
#                 152459.0,
#                 154319.0,
#                 155015.0,
#                 156073.0,
#                 156687.0,
#                 158446.0
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "normal": {
#                     "show": true,
#                     "position": "inside",
#                     "textStyle": {
#                         "color": "#000",
#                         "fontSize": 12
#                     },
#                     "formatter": "{b}:{c}"
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "markLine": {
#                 "data": []
#             },
#             "seriesId": 604426
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selectedMode": "multiple",
#             "show": true,
#             "left": "center",
#             "top": "top",
#             "orient": "horizontal",
#             "textStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "xAxis": [
#         {
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "boundaryGap": true,
#             "type": "value",
#             "splitLine": {
#                 "show": false
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "rotate": 0,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 12
#                 }
#             }
#         }
#     ],
#     "yAxis": [
#         {
#             "show": false,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "boundaryGap": true,
#             "type": "category",
#             "splitLine": {
#                 "show": true
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "formatter": "{value} ",
#                 "rotate": 0,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 12
#                 }
#             },
#             "data": [
#                 "\u5b98\u56ed",
#                 "\u897f\u5355",
#                 "\u4e07\u67f3",
#                 "\u6708\u575b",
#                 "\u9a6c\u7538",
#                 "\u5fb7\u80dc\u95e8",
#                 "\u516d\u94fa\u7095",
#                 "\u4ea4\u9053\u53e3",
#                 "\u91d1\u878d\u8857",
#                 "\u897f\u56db"
#             ]
#         }
#     ],
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ]
# };
# myChart_ce07283ac51a409888865fc8c53be047.setOption(option_ce07283ac51a409888865fc8c53be047);
#
#     });
# </script>

# %%
##筛选各区域内平均单价排名top5的位置
from pyecharts import Bar

pos_zone = data.groupby(['所在区',
                         '所在位置'])['单价(元/平米)'].mean().round(0).sort_values(
                             ascending=False).to_frame().reset_index()
pos_zone.columns = ['所在区', '所在位置', '单价(元/平米)']

top5_pos_zone=pos_zone.assign(rn=pos_zone.sort_values(['单价(元/平米)'], ascending=False)
          .groupby(['所在区'])
          .cumcount()+1)\
    .query('rn < =5').sort_values(['所在区','单价(元/平米)'],ascending=False)
print(top5_pos_zone)
# Out:
#       所在区      所在位置  单价(元/平米)  rn
# 189   顺义区     中央别墅区   49199.0   1
# 192   顺义区        天竺   48614.0   2
# 206   顺义区       后沙峪   44747.0   3
# 227   顺义区       顺义城   37503.0   4
# 230   顺义区      首都机场   35753.0   5
# 176   通州区      武夷花园   51751.0   1
# 198   通州区       临河里   47399.0   2
# 200   通州区        玉桥   46682.0   3
# 203   通州区  九棵树(家乐福)   45177.0   4
# 205   通州区      通州北苑   44800.0   5
# 0     西城区        西四  158446.0   1
# 1     西城区       金融街  156687.0   2
# 3     西城区       六铺炕  155015.0   3
# 4     西城区       德胜门  154319.0   4
# 5     西城区        马甸  152459.0   5
# 131  石景山区       玉泉路   69019.0   1
# 161  石景山区        鲁谷   57555.0   2
# 169  石景山区        老山   53317.0   3
# 170  石景山区        古城   52926.0   4
# 175  石景山区        八角   51787.0   5
# 7     海淀区        万柳  144334.0   1
# 19    海淀区       双榆树  125358.0   2
# 22    海淀区       圆明园  121230.0   3
# 24    海淀区       魏公村  117951.0   4
# 26    海淀区       五道口  115960.0   5
# 14    朝阳区       太阳宫  133663.0   1
# 51    朝阳区       三里屯  104958.0   2
# 71    朝阳区       东大桥   96031.0   3
# 73    朝阳区       三元桥   94683.0   4
# 75    朝阳区       和平里   92473.0   5
# 88    昌平区    奥林匹克公园   84994.0   1
# 158   昌平区        霍营   57964.0   2
# 160   昌平区       回龙观   57950.0   3
# 163   昌平区       立水桥   57022.0   4
# 164   昌平区       西三旗   56963.0   5
# 226   房山区        长阳   37957.0   1
# 238   房山区        良乡   30213.0   2
# 245   房山区        阎村   25229.0   3
# 248   房山区      房山其它   22388.0   4
# 249   房山区        城关   22232.0   5
# 142   大兴区   亦庄开发区其它   63725.0   1
# 180   大兴区       高米店   51235.0   2
# 185   大兴区        亦庄   50294.0   3
# 194   大兴区        旧宫   47733.0   4
# 201   大兴区        万源   45845.0   5
# 106   丰台区       菜户营   79141.0   1
# 107   丰台区        丽泽   78602.0   2
# 109   丰台区      右安门外   77528.0   3
# 111   丰台区       北大地   76694.0   4
# 115   丰台区       太平桥   74664.0   5
# 2     东城区       交道口  156073.0   1
# 13    东城区       金宝街  134081.0   2
# 15    东城区        东四  132476.0   3
# 18    东城区      朝阳门内  127662.0   4
# 21    东城区       和平里  122744.0   5

# %% [markdown]
# ## （4）所在小区对房价的影响

# %%
##分析北京二手房所在小区和单价
from pyecharts import Bar
#print (data.ix[:,['小区名称','所在区']])
house_perprice = data.groupby(['小区名称', '所在区', '所在位置'
                               ])['单价(元/平米)'].mean().round(0).sort_values(
                                   ascending=False).to_frame().reset_index()
house_perprice.columns = ['小区名称', '所在区', '所在位置', '单价(元/平米)']
top10_house = house_perprice.head(10).sort_values(
    ['单价(元/平米)'],
    ascending=False)  #.merge(data.ix[:,['小区名称','所在区']],on='小区名称',how = 'left')
top10_house
# Out:
#         小区名称  所在区 所在位置  单价(元/平米)
# 0   龙湖唐宁one   海淀区  五道口  179932.0
# 1  五路通北街3号院   西城区  六铺炕  179844.0
# 2       京畿道   西城区  金融街  179798.0
# 3      大井胡同   西城区  六铺炕  179737.0
# 4  新外大街乙8号院   西城区   马甸  179723.0
# 5      金融世家   西城区  木樨地  179266.0
# 6        一瓶   西城区  陶然亭  177928.0
# 7     丰汇园小区   西城区  金融街  177866.0
# 8     南沙沟小区   西城区   月坛  177676.0
# 9      金龙公寓   西城区  金融街  177505.0

# %%
bar = Bar('北京二手房平均单价TOP10小区(元/平米)', width=500)
bar.add('',
        top10_house['小区名称'],
        top10_house['单价(元/平米)'],
        is_label_show=True,
        label_text_color='#000',
        label_pos='inside',
        label_formatter='{b}:{c}',
        is_yaxis_show=False,
        is_convert=True)
bar
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="c05bf8563ae740b386ea84ce23e1de6b" style="width:500px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_c05bf8563ae740b386ea84ce23e1de6b = echarts.init(document.getElementById('c05bf8563ae740b386ea84ce23e1de6b'), 'light', {renderer: 'canvas'});
#
# var option_c05bf8563ae740b386ea84ce23e1de6b = {
#     "title": [
#         {
#             "text": "\u5317\u4eac\u4e8c\u624b\u623f\u5e73\u5747\u5355\u4ef7TOP10\u5c0f\u533a(\u5143/\u5e73\u7c73)",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "\u4e0b\u8f7d\u56fe\u7247"
#             },
#             "restore": {
#                 "show": true
#             },
#             "dataView": {
#                 "show": true
#             }
#         }
#     },
#     "series_id": 2980104,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "bar",
#             "data": [
#                 179932.0,
#                 179844.0,
#                 179798.0,
#                 179737.0,
#                 179723.0,
#                 179266.0,
#                 177928.0,
#                 177866.0,
#                 177676.0,
#                 177505.0
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "normal": {
#                     "show": true,
#                     "position": "inside",
#                     "textStyle": {
#                         "color": "#000",
#                         "fontSize": 12
#                     },
#                     "formatter": "{b}:{c}"
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "markLine": {
#                 "data": []
#             },
#             "seriesId": 2980104
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selectedMode": "multiple",
#             "show": true,
#             "left": "center",
#             "top": "top",
#             "orient": "horizontal",
#             "textStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "xAxis": [
#         {
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "boundaryGap": true,
#             "type": "value",
#             "splitLine": {
#                 "show": false
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "rotate": 0,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 12
#                 }
#             }
#         }
#     ],
#     "yAxis": [
#         {
#             "show": false,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "boundaryGap": true,
#             "type": "category",
#             "splitLine": {
#                 "show": true
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "formatter": "{value} ",
#                 "rotate": 0,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 12
#                 }
#             },
#             "data": [
#                 "\u9f99\u6e56\u5510\u5b81one ",
#                 "\u4e94\u8def\u901a\u5317\u88573\u53f7\u9662 ",
#                 "\u4eac\u757f\u9053 ",
#                 "\u5927\u4e95\u80e1\u540c ",
#                 "\u65b0\u5916\u5927\u8857\u4e598\u53f7\u9662 ",
#                 "\u91d1\u878d\u4e16\u5bb6 ",
#                 "\u4e00\u74f6 ",
#                 "\u4e30\u6c47\u56ed\u5c0f\u533a ",
#                 "\u5357\u6c99\u6c9f\u5c0f\u533a ",
#                 "\u91d1\u9f99\u516c\u5bd3 "
#             ]
#         }
#     ],
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ]
# };
# myChart_c05bf8563ae740b386ea84ce23e1de6b.setOption(option_c05bf8563ae740b386ea84ce23e1de6b);
#
#     });
# </script>

# %%
##筛选各区域内平均单价排名前五的小区
from pyecharts import Bar

house_zone = data.groupby(['所在区',
                           '小区名称'])['单价(元/平米)'].mean().round(0).sort_values(
                               ascending=False).to_frame().reset_index()
house_zone.columns = ['所在区', '小区名称', '单价(元/平米)']

top5_hosue_zone=house_zone.assign(rn=house_zone.sort_values(['单价(元/平米)'], ascending=False)
          .groupby(['所在区'])
          .cumcount()+1)\
    .query('rn < =5').sort_values(['所在区','单价(元/平米)'],ascending=False)
print(top5_hosue_zone)
# Out:
#        所在区          小区名称  单价(元/平米)  rn
# 260    顺义区       金地中央世家   121714.0   1
# 489    顺义区       棕榈滩金棕榈   107397.0   2
# 832    顺义区        龙湖滟澜山    86913.0   3
# 1024   顺义区         龙湾别墅    76194.0   4
# 1176   顺义区         嘉浩别墅    69808.0   5
# 1079   通州区          百合湾    73980.0   1
# 1098   通州区      金隅花石匠一期    73425.0   2
# 1173   通州区       京贸国际公馆    69860.0   3
# 1223   通州区        台湖银河湾    67794.0   4
# 1263   通州区    通州万国城MOMA    66469.0   5
# 1      西城区     五路通北街3号院   179844.0   1
# 2      西城区          京畿道   179798.0   2
# 3      西城区         大井胡同   179737.0   3
# 4      西城区     新外大街乙8号院   179723.0   4
# 5      西城区         金融世家   179266.0   5
# 426   石景山区       远洋天著春秋   110303.0   1
# 705   石景山区        远洋沁山水    94693.0   2
# 763   石景山区         天和景园    90734.0   3
# 854   石景山区       玉泉新城B区    85411.0   4
# 941   石景山区    中海寰宇天下御山府    81334.0   5
# 0      海淀区      龙湖唐宁one   179932.0   1
# 30     海淀区         康桥水郡   165030.0   2
# 69     海淀区         蜂鸟家园   156148.0   3
# 104    海淀区      知春路82号院   147758.0   4
# 108    海淀区         锋尚国际   146965.0   5
# 12     朝阳区       太阳公元北区   176290.0   1
# 143    朝阳区          丰和园   139685.0   2
# 170    朝阳区          红玺台   134880.0   3
# 172    朝阳区        金茂府北区   134710.0   4
# 207    朝阳区      远洋万和城B区   129740.0   5
# 858    昌平区       招商嘉铭珑原    84994.0   1
# 862    昌平区       金域华府二期    84714.0   2
# 988    昌平区      龙城花园中五区    78592.0   3
# 1048   昌平区     京投发展公园悦府    75316.0   4
# 1056   昌平区     首开国风美唐二期    75007.0   5
# 1313   房山区         五矿名品    64130.0   1
# 1471   房山区      芭蕾雨悦都北区    58704.0   2
# 1741   房山区      北京城建徜徉墅    51719.0   3
# 1772   房山区  长阳半岛怡和南路8号院    51106.0   4
# 1866   房山区        金鸽园小区    49090.0   5
# 427    大兴区         金茂逸墅   110297.0   1
# 741    大兴区        亦庄金茂府    92191.0   2
# 1029   大兴区       万科金域东郡    76122.0   3
# 1039   大兴区      亦庄金茂悦南区    75653.0   4
# 1055   大兴区      亦庄金茂悦北区    75035.0   5
# 179    丰台区          昆仑域   134058.0   1
# 543    丰台区         保利百合   103590.0   2
# 582    丰台区          益丰苑   101505.0   3
# 625    丰台区       万年花城五期    99396.0   4
# 626    丰台区         风荷曲苑    99366.0   5
# 24     东城区        使馆壹号院   167440.0   1
# 37     东城区       交道口东大街   163658.0   2
# 56     东城区         草厂八条   159510.0   3
# 86     东城区         长安太和   151356.0   4
# 129    东城区        和平里五区   142399.0   5

# %% [markdown]
# ## （5）电梯对房价的影响

# %%
from pyecharts import Bar, Pie

house_loft = data.groupby(['有无电梯',
                           '所在区'])['单价(元/平米)'].agg(['size', 'mean', 'sum'
                                                    ]).round(0).reset_index()
house_loft.columns = ['有无电梯', '所在区', '数量', '单价', '总价之和']
print(house_loft)
# Out:
#    有无电梯   所在区   数量        单价      总价之和
# 0   无电梯   东城区  157  102075.0  16025778
# 1   无电梯   丰台区  159   56517.0   8986164
# 2   无电梯   大兴区  337   40329.0  13590940
# 3   无电梯   房山区  268   25028.0   6707595
# 4   无电梯   昌平区  395   44281.0  17490829
# 5   无电梯   朝阳区  229   66947.0  15330952
# 6   无电梯   海淀区  218   96801.0  21102584
# 7   无电梯  石景山区  508   48874.0  24827944
# 8   无电梯   西城区  396  132289.0  52386363
# 9   无电梯   通州区  250   40210.0  10052624
# 10  无电梯   顺义区  393   36965.0  14527145
# 11  有电梯   东城区  406  105450.0  42812723
# 12  有电梯   丰台区  508   63178.0  32094488
# 13  有电梯   大兴区  540   46609.0  25168725
# 14  有电梯   房山区  484   34401.0  16650231
# 15  有电梯   昌平区  418   50812.0  21239511
# 16  有电梯   朝阳区  638   73548.0  46923440
# 17  有电梯   海淀区  362   97727.0  35377277
# 18  有电梯  石景山区  396   57916.0  22934774
# 19  有电梯   西城区  365  127465.0  46524660
# 20  有电梯   通州区  552   45038.0  24860957
# 21  有电梯   顺义区  439   38676.0  16978686

# %%
pie = Pie(
    "北京二手房有无电梯房源数量(套)",
    width=700,
    height=400,
)
pie.add("", ['有电梯', '无电梯'], [
    house_loft[house_loft['有无电梯'] == '有电梯']['数量'].sum(),
    house_loft[house_loft['有无电梯'] == '无电梯']['数量'].sum()
],
        is_label_show=True,
        is_toolbox_show=False,
        label_formatter='{b}:{c},{d}%')
pie
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="9b8fd652f5d146289fca22fd0e7a6670" style="width:700px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_9b8fd652f5d146289fca22fd0e7a6670 = echarts.init(document.getElementById('9b8fd652f5d146289fca22fd0e7a6670'), 'light', {renderer: 'canvas'});
#
# var option_9b8fd652f5d146289fca22fd0e7a6670 = {
#     "title": [
#         {
#             "text": "\u5317\u4eac\u4e8c\u624b\u623f\u6709\u65e0\u7535\u68af\u623f\u6e90\u6570\u91cf(\u5957)",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "series_id": 4676037,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "pie",
#             "data": [
#                 {
#                     "name": "\u6709\u7535\u68af",
#                     "value": 5108.0
#                 },
#                 {
#                     "name": "\u65e0\u7535\u68af",
#                     "value": 3310.0
#                 }
#             ],
#             "radius": [
#                 "0%",
#                 "75%"
#             ],
#             "center": [
#                 "50%",
#                 "50%"
#             ],
#             "label": {
#                 "normal": {
#                     "show": true,
#                     "position": "outside",
#                     "textStyle": {
#                         "fontSize": 12
#                     },
#                     "formatter": "{b}:{c},{d}%"
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     },
#                     "formatter": "{b}: {d}%"
#                 }
#             },
#             "seriesId": 4676037
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u6709\u7535\u68af",
#                 "\u65e0\u7535\u68af"
#             ],
#             "selectedMode": "multiple",
#             "show": true,
#             "left": "center",
#             "top": "top",
#             "orient": "horizontal",
#             "textStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ]
# };
# myChart_9b8fd652f5d146289fca22fd0e7a6670.setOption(option_9b8fd652f5d146289fca22fd0e7a6670);
#
#     });
# </script>

# %%
bar = Bar('北京各区二手房有无电梯房源数量(套)', width=900)
bar.add('有电梯',
        house_loft[house_loft['有无电梯'] == '有电梯']['所在区'],
        house_loft[house_loft['有无电梯'] == '有电梯']['数量'],
        is_label_show=True,
        label_text_color='#000',
        label_pos='inside',
        is_stack=True)
bar.add('无电梯',
        house_loft[house_loft['有无电梯'] == '无电梯']['所在区'],
        house_loft[house_loft['有无电梯'] == '无电梯']['数量'],
        is_label_show=True,
        is_stack=True)
bar
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="459632c0fb1c4511b161b74a58cee2d0" style="width:900px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_459632c0fb1c4511b161b74a58cee2d0 = echarts.init(document.getElementById('459632c0fb1c4511b161b74a58cee2d0'), 'light', {renderer: 'canvas'});
#
# var option_459632c0fb1c4511b161b74a58cee2d0 = {
#     "title": [
#         {
#             "text": "\u5317\u4eac\u5404\u533a\u4e8c\u624b\u623f\u6709\u65e0\u7535\u68af\u623f\u6e90\u6570\u91cf(\u5957)",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "\u4e0b\u8f7d\u56fe\u7247"
#             },
#             "restore": {
#                 "show": true
#             },
#             "dataView": {
#                 "show": true
#             }
#         }
#     },
#     "series_id": 569780,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u6709\u7535\u68af",
#             "data": [
#                 406.0,
#                 508.0,
#                 540.0,
#                 484.0,
#                 418.0,
#                 638.0,
#                 362.0,
#                 396.0,
#                 365.0,
#                 552.0,
#                 439.0
#             ],
#             "stack": "stack_569780",
#             "barCategoryGap": "20%",
#             "label": {
#                 "normal": {
#                     "show": true,
#                     "position": "inside",
#                     "textStyle": {
#                         "color": "#000",
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "markLine": {
#                 "data": []
#             },
#             "seriesId": 569780
#         },
#         {
#             "type": "bar",
#             "name": "\u65e0\u7535\u68af",
#             "data": [
#                 157.0,
#                 159.0,
#                 337.0,
#                 268.0,
#                 395.0,
#                 229.0,
#                 218.0,
#                 508.0,
#                 396.0,
#                 250.0,
#                 393.0
#             ],
#             "stack": "stack_569780",
#             "barCategoryGap": "20%",
#             "label": {
#                 "normal": {
#                     "show": true,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "markLine": {
#                 "data": []
#             },
#             "seriesId": 569780
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u6709\u7535\u68af",
#                 "\u65e0\u7535\u68af"
#             ],
#             "selectedMode": "multiple",
#             "show": true,
#             "left": "center",
#             "top": "top",
#             "orient": "horizontal",
#             "textStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "xAxis": [
#         {
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "boundaryGap": true,
#             "type": "category",
#             "splitLine": {
#                 "show": false
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "rotate": 0,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 12
#                 }
#             },
#             "data": [
#                 "\u4e1c\u57ce\u533a",
#                 "\u4e30\u53f0\u533a",
#                 "\u5927\u5174\u533a",
#                 "\u623f\u5c71\u533a",
#                 "\u660c\u5e73\u533a",
#                 "\u671d\u9633\u533a",
#                 "\u6d77\u6dc0\u533a",
#                 "\u77f3\u666f\u5c71\u533a",
#                 "\u897f\u57ce\u533a",
#                 "\u901a\u5dde\u533a",
#                 "\u987a\u4e49\u533a"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "boundaryGap": true,
#             "type": "value",
#             "splitLine": {
#                 "show": true
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "formatter": "{value} ",
#                 "rotate": 0,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 12
#                 }
#             }
#         }
#     ],
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ]
# };
# myChart_459632c0fb1c4511b161b74a58cee2d0.setOption(option_459632c0fb1c4511b161b74a58cee2d0);
#
#     });
# </script>

# %%
bar = Bar('北京各区有无电梯二手房平均单价(元/平米)', width=900)
bar.add('有电梯',
        house_loft[house_loft['有无电梯'] == '有电梯']['所在区'],
        house_loft[house_loft['有无电梯'] == '有电梯']['单价'],
        is_label_show=True,
        mark_line=['average'],
        is_toolbox_show=False)
bar.add('无电梯',
        house_loft[house_loft['有无电梯'] == '无电梯']['所在区'],
        house_loft[house_loft['有无电梯'] == '无电梯']['单价'],
        is_label_show=True,
        mark_line=['average'],
        is_toolbox_show=False)
bar
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="2135f80035ce4f5f94d149362be195ae" style="width:900px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_2135f80035ce4f5f94d149362be195ae = echarts.init(document.getElementById('2135f80035ce4f5f94d149362be195ae'), 'light', {renderer: 'canvas'});
#
# var option_2135f80035ce4f5f94d149362be195ae = {
#     "title": [
#         {
#             "text": "\u5317\u4eac\u5404\u533a\u6709\u65e0\u7535\u68af\u4e8c\u624b\u623f\u5e73\u5747\u5355\u4ef7(\u5143/\u5e73\u7c73)",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "series_id": 3749544,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u6709\u7535\u68af",
#             "data": [
#                 105450.0,
#                 63178.0,
#                 46609.0,
#                 34401.0,
#                 50812.0,
#                 73548.0,
#                 97727.0,
#                 57916.0,
#                 127465.0,
#                 45038.0,
#                 38676.0
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "normal": {
#                     "show": true,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "markLine": {
#                 "data": [
#                     {
#                         "type": "average",
#                         "name": "mean-Value"
#                     }
#                 ],
#                 "symbolSize": 10
#             },
#             "seriesId": 3749544
#         },
#         {
#             "type": "bar",
#             "name": "\u65e0\u7535\u68af",
#             "data": [
#                 102075.0,
#                 56517.0,
#                 40329.0,
#                 25028.0,
#                 44281.0,
#                 66947.0,
#                 96801.0,
#                 48874.0,
#                 132289.0,
#                 40210.0,
#                 36965.0
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "normal": {
#                     "show": true,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "markLine": {
#                 "data": [
#                     {
#                         "type": "average",
#                         "name": "mean-Value"
#                     }
#                 ],
#                 "symbolSize": 10
#             },
#             "seriesId": 3749544
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u6709\u7535\u68af",
#                 "\u65e0\u7535\u68af"
#             ],
#             "selectedMode": "multiple",
#             "show": true,
#             "left": "center",
#             "top": "top",
#             "orient": "horizontal",
#             "textStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "xAxis": [
#         {
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "boundaryGap": true,
#             "type": "category",
#             "splitLine": {
#                 "show": false
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "rotate": 0,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 12
#                 }
#             },
#             "data": [
#                 "\u4e1c\u57ce\u533a",
#                 "\u4e30\u53f0\u533a",
#                 "\u5927\u5174\u533a",
#                 "\u623f\u5c71\u533a",
#                 "\u660c\u5e73\u533a",
#                 "\u671d\u9633\u533a",
#                 "\u6d77\u6dc0\u533a",
#                 "\u77f3\u666f\u5c71\u533a",
#                 "\u897f\u57ce\u533a",
#                 "\u901a\u5dde\u533a",
#                 "\u987a\u4e49\u533a"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "boundaryGap": true,
#             "type": "value",
#             "splitLine": {
#                 "show": true
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "formatter": "{value} ",
#                 "rotate": 0,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 12
#                 }
#             }
#         }
#     ],
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ]
# };
# myChart_2135f80035ce4f5f94d149362be195ae.setOption(option_2135f80035ce4f5f94d149362be195ae);
#
#     });
# </script>

# %% [markdown]
# ## （6）装修类型对房价的影响

# %%
from pyecharts import Bar, Pie
fit_up_price = pd.merge(data.groupby(
    ['装修'])['单价(元/平米)'].mean().round(0).sort_values(
        ascending=False).to_frame().reset_index(),
                        data.groupby(['装修']).size().to_frame().reset_index(),
                        on='装修')
fit_up_price.columns = ['装修', '单价(元/平米)', '计数']
print(fit_up_price)
# Out:
#    装修  单价(元/平米)    计数
# 0  精装   65471.0  4444
# 1  其他   61811.0   415
# 2  简装   61468.0  3335
# 3  毛坯   49078.0   224

# %%
pie = Pie(
    "北京二手房各装修类型房源数量统计",
    width=700,
    height=400,
)
pie.add("",
        fit_up_price['装修'],
        fit_up_price['计数'],
        is_label_show=True,
        legend_orient="vertical",
        legend_pos="right",
        is_toolbox_show=False,
        label_formatter='{b}:{c},{d}%')
pie
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="3bcce71dfa0b45dfa61da59bbe9e8f84" style="width:700px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_3bcce71dfa0b45dfa61da59bbe9e8f84 = echarts.init(document.getElementById('3bcce71dfa0b45dfa61da59bbe9e8f84'), 'light', {renderer: 'canvas'});
#
# var option_3bcce71dfa0b45dfa61da59bbe9e8f84 = {
#     "title": [
#         {
#             "text": "\u5317\u4eac\u4e8c\u624b\u623f\u5404\u88c5\u4fee\u7c7b\u578b\u623f\u6e90\u6570\u91cf\u7edf\u8ba1",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "series_id": 3646788,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "pie",
#             "data": [
#                 {
#                     "name": "\u7cbe\u88c5",
#                     "value": 4444
#                 },
#                 {
#                     "name": "\u5176\u4ed6",
#                     "value": 415
#                 },
#                 {
#                     "name": "\u7b80\u88c5",
#                     "value": 3335
#                 },
#                 {
#                     "name": "\u6bdb\u576f",
#                     "value": 224
#                 }
#             ],
#             "radius": [
#                 "0%",
#                 "75%"
#             ],
#             "center": [
#                 "50%",
#                 "50%"
#             ],
#             "label": {
#                 "normal": {
#                     "show": true,
#                     "position": "outside",
#                     "textStyle": {
#                         "fontSize": 12
#                     },
#                     "formatter": "{b}:{c},{d}%"
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     },
#                     "formatter": "{b}: {d}%"
#                 }
#             },
#             "seriesId": 3646788
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u7cbe\u88c5",
#                 "\u5176\u4ed6",
#                 "\u7b80\u88c5",
#                 "\u6bdb\u576f"
#             ],
#             "selectedMode": "multiple",
#             "show": true,
#             "left": "right",
#             "top": "top",
#             "orient": "vertical",
#             "textStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ]
# };
# myChart_3bcce71dfa0b45dfa61da59bbe9e8f84.setOption(option_3bcce71dfa0b45dfa61da59bbe9e8f84);
#
#     });
# </script>

# %%
##统计各装修类型房屋数量及房价
house_fitup = data.groupby(['所在区',
                            '装修'])['单价(元/平米)'].agg(['size', 'mean', 'sum'
                                                    ]).round(0).reset_index()
house_fitup.columns = ['所在区', '装修', '数量', '单价', '总价之和']
print(house_fitup)
# Out:
#      所在区  装修   数量        单价      总价之和
# 0    东城区  其他   36  107250.0   3860983
# 1    东城区  毛坯    9   97862.0    880757
# 2    东城区  简装  216   98858.0  21353280
# 3    东城区  精装  302  108422.0  32743481
# 4    丰台区  其他    6   67694.0    406166
# 5    丰台区  毛坯   11   55170.0    606873
# 6    丰台区  简装  320   59180.0  18937593
# 7    丰台区  精装  330   64030.0  21130020
# 8    大兴区  其他   60   40103.0   2406196
# 9    大兴区  毛坯   13   39902.0    518724
# 10   大兴区  简装  398   41448.0  16496422
# 11   大兴区  精装  406   47631.0  19338323
# 12   房山区  其他   32   31133.0    996245
# 13   房山区  毛坯   57   28768.0   1639785
# 14   房山区  简装  212   28710.0   6086460
# 15   房山区  精装  451   32451.0  14635336
# 16   昌平区  其他   34   44544.0   1514500
# 17   昌平区  毛坯   16   42456.0    679297
# 18   昌平区  简装  324   46272.0  14991987
# 19   昌平区  精装  439   49076.0  21544556
# 20   朝阳区  其他   10   79306.0    793063
# 21   朝阳区  毛坯   14   67003.0    938044
# 22   朝阳区  简装  291   66693.0  19407613
# 23   朝阳区  精装  552   74485.0  41115672
# 24   海淀区  其他    7   95936.0    671550
# 25   海淀区  毛坯    6  112566.0    675398
# 26   海淀区  简装  226   92807.0  20974457
# 27   海淀区  精装  341  100171.0  34158456
# 28  石景山区  其他   89   49100.0   4369859
# 29  石景山区  毛坯   12   57713.0    692558
# 30  石景山区  简装  442   51268.0  22660461
# 31  石景山区  精装  361   55512.0  20039840
# 32   西城区  其他   56  131880.0   7385253
# 33   西城区  毛坯   12  123903.0   1486836
# 34   西城区  简装  327  126668.0  41420336
# 35   西城区  精装  366  132838.0  48618598
# 36   通州区  其他   27   36874.0    995599
# 37   通州区  毛坯   10   45430.0    454302
# 38   通州区  简装  287   42261.0  12128980
# 39   通州区  精装  478   44633.0  21334700
# 40   顺义区  其他   58   38832.0   2252228
# 41   顺义区  毛坯   64   37828.0   2420972
# 42   顺义区  简装  292   36094.0  10539508
# 43   顺义区  精装  418   38979.0  16293123

# %%
bar = Bar('北京各区二手房精/简装修房源数量(套)', width=900)
bar.add('精装',
        house_fitup[house_fitup['装修'] == '精装']['所在区'],
        house_fitup[house_fitup['装修'] == '精装']['数量'],
        is_label_show=True,
        label_text_color='#000',
        label_pos='inside',
        is_stack=True)
bar.add('简装',
        house_fitup[house_fitup['装修'] == '简装']['所在区'],
        house_fitup[house_fitup['装修'] == '简装']['数量'],
        is_label_show=True,
        label_text_color='#000',
        label_pos='inside',
        is_stack=True)
#bar.add('毛坯',house_fitup[house_fitup['装修']=='毛坯']['所在区'],house_fitup[house_fitup['装修']=='毛坯']['数量'],is_label_show=True,is_stack=True)
bar
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="22ee8ec6354d49219eb20ccee1f41b9c" style="width:900px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_22ee8ec6354d49219eb20ccee1f41b9c = echarts.init(document.getElementById('22ee8ec6354d49219eb20ccee1f41b9c'), 'light', {renderer: 'canvas'});
#
# var option_22ee8ec6354d49219eb20ccee1f41b9c = {
#     "title": [
#         {
#             "text": "\u5317\u4eac\u5404\u533a\u4e8c\u624b\u623f\u7cbe/\u7b80\u88c5\u4fee\u623f\u6e90\u6570\u91cf(\u5957)",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "\u4e0b\u8f7d\u56fe\u7247"
#             },
#             "restore": {
#                 "show": true
#             },
#             "dataView": {
#                 "show": true
#             }
#         }
#     },
#     "series_id": 4627713,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u7cbe\u88c5",
#             "data": [
#                 302.0,
#                 330.0,
#                 406.0,
#                 451.0,
#                 439.0,
#                 552.0,
#                 341.0,
#                 361.0,
#                 366.0,
#                 478.0,
#                 418.0
#             ],
#             "stack": "stack_4627713",
#             "barCategoryGap": "20%",
#             "label": {
#                 "normal": {
#                     "show": true,
#                     "position": "inside",
#                     "textStyle": {
#                         "color": "#000",
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "markLine": {
#                 "data": []
#             },
#             "seriesId": 4627713
#         },
#         {
#             "type": "bar",
#             "name": "\u7b80\u88c5",
#             "data": [
#                 216.0,
#                 320.0,
#                 398.0,
#                 212.0,
#                 324.0,
#                 291.0,
#                 226.0,
#                 442.0,
#                 327.0,
#                 287.0,
#                 292.0
#             ],
#             "stack": "stack_4627713",
#             "barCategoryGap": "20%",
#             "label": {
#                 "normal": {
#                     "show": true,
#                     "position": "inside",
#                     "textStyle": {
#                         "color": "#000",
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "markLine": {
#                 "data": []
#             },
#             "seriesId": 4627713
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u7cbe\u88c5",
#                 "\u7b80\u88c5"
#             ],
#             "selectedMode": "multiple",
#             "show": true,
#             "left": "center",
#             "top": "top",
#             "orient": "horizontal",
#             "textStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "xAxis": [
#         {
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "boundaryGap": true,
#             "type": "category",
#             "splitLine": {
#                 "show": false
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "rotate": 0,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 12
#                 }
#             },
#             "data": [
#                 "\u4e1c\u57ce\u533a",
#                 "\u4e30\u53f0\u533a",
#                 "\u5927\u5174\u533a",
#                 "\u623f\u5c71\u533a",
#                 "\u660c\u5e73\u533a",
#                 "\u671d\u9633\u533a",
#                 "\u6d77\u6dc0\u533a",
#                 "\u77f3\u666f\u5c71\u533a",
#                 "\u897f\u57ce\u533a",
#                 "\u901a\u5dde\u533a",
#                 "\u987a\u4e49\u533a"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "boundaryGap": true,
#             "type": "value",
#             "splitLine": {
#                 "show": true
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "formatter": "{value} ",
#                 "rotate": 0,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 12
#                 }
#             }
#         }
#     ],
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ]
# };
# myChart_22ee8ec6354d49219eb20ccee1f41b9c.setOption(option_22ee8ec6354d49219eb20ccee1f41b9c);
#
#     });
# </script>

# %%
bar = Bar("北京各区二手房精/简装修房源单价(元/平米)", width=900)
bar.add('精装',
        house_fitup[house_fitup['装修'] == '精装']['所在区'],
        house_fitup[house_fitup['装修'] == '精装']['单价'],
        is_label_show=True,
        label_text_color='#000',
        bar_category_gap='30%',
        mark_line=['average'],
        is_toolbox_show=False)
bar.add('简装',
        house_fitup[house_fitup['装修'] == '简装']['所在区'],
        house_fitup[house_fitup['装修'] == '简装']['单价'],
        is_label_show=True,
        label_text_color='#000',
        label_pos='inside',
        bar_category_gap='30%',
        mark_line=['average'],
        is_toolbox_show=False)
#bar.add('毛坯',house_fitup[house_fitup['装修']=='毛坯']['所在区'],house_fitup[house_fitup['装修']=='毛坯']['单价'],is_label_show=True,label_text_color='#000',bar_category_gap='30%')
bar
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="5463ad83737e48afbf9cbf38663401ac" style="width:900px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_5463ad83737e48afbf9cbf38663401ac = echarts.init(document.getElementById('5463ad83737e48afbf9cbf38663401ac'), 'light', {renderer: 'canvas'});
#
# var option_5463ad83737e48afbf9cbf38663401ac = {
#     "title": [
#         {
#             "text": "\u5317\u4eac\u5404\u533a\u4e8c\u624b\u623f\u7cbe/\u7b80\u88c5\u4fee\u623f\u6e90\u5355\u4ef7(\u5143/\u5e73\u7c73)",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "series_id": 6076620,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u7cbe\u88c5",
#             "data": [
#                 108422.0,
#                 64030.0,
#                 47631.0,
#                 32451.0,
#                 49076.0,
#                 74485.0,
#                 100171.0,
#                 55512.0,
#                 132838.0,
#                 44633.0,
#                 38979.0
#             ],
#             "barCategoryGap": "30%",
#             "label": {
#                 "normal": {
#                     "show": true,
#                     "position": "top",
#                     "textStyle": {
#                         "color": "#000",
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "markLine": {
#                 "data": [
#                     {
#                         "type": "average",
#                         "name": "mean-Value"
#                     }
#                 ],
#                 "symbolSize": 10
#             },
#             "seriesId": 6076620
#         },
#         {
#             "type": "bar",
#             "name": "\u7b80\u88c5",
#             "data": [
#                 98858.0,
#                 59180.0,
#                 41448.0,
#                 28710.0,
#                 46272.0,
#                 66693.0,
#                 92807.0,
#                 51268.0,
#                 126668.0,
#                 42261.0,
#                 36094.0
#             ],
#             "barCategoryGap": "30%",
#             "label": {
#                 "normal": {
#                     "show": true,
#                     "position": "inside",
#                     "textStyle": {
#                         "color": "#000",
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "markLine": {
#                 "data": [
#                     {
#                         "type": "average",
#                         "name": "mean-Value"
#                     }
#                 ],
#                 "symbolSize": 10
#             },
#             "seriesId": 6076620
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u7cbe\u88c5",
#                 "\u7b80\u88c5"
#             ],
#             "selectedMode": "multiple",
#             "show": true,
#             "left": "center",
#             "top": "top",
#             "orient": "horizontal",
#             "textStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "xAxis": [
#         {
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "boundaryGap": true,
#             "type": "category",
#             "splitLine": {
#                 "show": false
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "rotate": 0,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 12
#                 }
#             },
#             "data": [
#                 "\u4e1c\u57ce\u533a",
#                 "\u4e30\u53f0\u533a",
#                 "\u5927\u5174\u533a",
#                 "\u623f\u5c71\u533a",
#                 "\u660c\u5e73\u533a",
#                 "\u671d\u9633\u533a",
#                 "\u6d77\u6dc0\u533a",
#                 "\u77f3\u666f\u5c71\u533a",
#                 "\u897f\u57ce\u533a",
#                 "\u901a\u5dde\u533a",
#                 "\u987a\u4e49\u533a"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "boundaryGap": true,
#             "type": "value",
#             "splitLine": {
#                 "show": true
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "formatter": "{value} ",
#                 "rotate": 0,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 12
#                 }
#             }
#         }
#     ],
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ]
# };
# myChart_5463ad83737e48afbf9cbf38663401ac.setOption(option_5463ad83737e48afbf9cbf38663401ac);
#
#     });
# </script>

# %% [markdown]
# ## （7）房屋面积对房价的影响

# %%
from pyecharts import Scatter
area = set(data['所在区'].values.tolist())
for i in area:
    cor = round(
        data[data['所在区'] == i]['面积(平米)'].corr(
            data[data['所在区'] == i]['单价(元/平米)']), 2)
    print(i, cor)

print(data['面积(平米)'].corr(data['单价(元/平米)']))
# Out:
# 朝阳区 0.24
# 昌平区 -0.21
# 丰台区 0.19
# 石景山区 0.38
# 通州区 0.08
# 东城区 -0.23
# 海淀区 -0.02
# 大兴区 0.06
# 西城区 -0.19
# 顺义区 0.16
# 房山区 -0.07
# -0.13894266409375727

# %%
#修改所在区名称，画各个区房屋面积与房价的散点图
#v1 = data[data['所在区']=='大兴区']['面积(平米)']
#v2 = data[data['所在区']=='大兴区']['单价(元/平米)']/10000

v1 = data['面积(平米)']
v2 = data['单价(元/平米)'] / 10000
scatter = Scatter(width=500, height=300)
scatter.add("房屋面积与单价关系",
            v1,
            v2,
            legend_pos="40%",
            yaxis_name='单价(万元/平米)',
            yaxis_name_pos='end',
            xaxis_name='面积')
scatter
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="addde754febc41b7a2317e658cc9c84f" style="width:500px;height:300px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_addde754febc41b7a2317e658cc9c84f = echarts.init(document.getElementById('addde754febc41b7a2317e658cc9c84f'), 'light', {renderer: 'canvas'});
#
# var option_addde754febc41b7a2317e658cc9c84f = {
#     "title": [
#         {
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "\u4e0b\u8f7d\u56fe\u7247"
#             },
#             "restore": {
#                 "show": true
#             },
#             "dataView": {
#                 "show": true
#             }
#         }
#     },
#     "series_id": 7257951,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "scatter",
#             "name": "\u623f\u5c4b\u9762\u79ef\u4e0e\u5355\u4ef7\u5173\u7cfb",
#             "symbol": "circle",
#             "symbolSize": 10,
#             "data": [
#                 [
#                     80.85,
#                     10.6989
#                 ],
#                 [
#                     39.46,
#                     15.0786
#                 ],
#                 [
#                     73.85,
#                     12.6608
#                 ],
#                 [
#                     132.32,
#                     10.2026
#                 ],
#                 [
#                     149.92,
#                     6.8704
#                 ],
#                 [
#                     221.86,
#                     7.7527
#                 ],
#                 [
#                     56.04,
#                     9.7788
#                 ],
#                 [
#                     88.96,
#                     7.9812
#                 ],
#                 [
#                     60.72,
#                     8.8604
#                 ],
#                 [
#                     60.06,
#                     10.4063
#                 ],
#                 [
#                     106.08,
#                     9.2007
#                 ],
#                 [
#                     58.15,
#                     9.9743
#                 ],
#                 [
#                     36.8,
#                     9.375
#                 ],
#                 [
#                     57.53,
#                     13.5582
#                 ],
#                 [
#                     62.15,
#                     9.815
#                 ],
#                 [
#                     69.96,
#                     11.5781
#                 ],
#                 [
#                     67.29,
#                     12.9292
#                 ],
#                 [
#                     80.85,
#                     10.6989
#                 ],
#                 [
#                     39.46,
#                     15.0786
#                 ],
#                 [
#                     73.85,
#                     12.6608
#                 ],
#                 [
#                     132.32,
#                     10.2026
#                 ],
#                 [
#                     149.92,
#                     6.8704
#                 ],
#                 [
#                     221.86,
#                     7.7527
#                 ],
#                 [
#                     56.04,
#                     9.7788
#                 ],
#                 [
#                     88.96,
#                     7.9812
#                 ],
#                 [
#                     60.72,
#                     8.8604
#                 ],
#                 [
#                     60.06,
#                     10.4063
#                 ],
#                 [
#                     106.08,
#                     9.2007
#                 ],
#                 [
#                     58.15,
#                     9.9743
#                 ],
#                 [
#                     36.8,
#                     9.375
#                 ],
#                 [
#                     57.53,
#                     13.5582
#                 ],
#                 [
#                     62.15,
#                     9.815
#                 ],
#                 [
#                     69.96,
#                     11.5781
#                 ],
#                 [
#                     67.29,
#                     12.9292
#                 ],
#                 [
#                     52.22,
#                     12.2559
#                 ],
#                 [
#                     71.44,
#                     13.5779
#                 ],
#                 [
#                     90.03,
#                     11.3296
#                 ],
#                 [
#                     61.23,
#                     10.5831
#                 ],
#                 [
#                     147.89,
#                     8.0466
#                 ],
#                 [
#                     55.31,
#                     6.7619
#                 ],
#                 [
#                     68.11,
#                     9.2498
#                 ],
#                 [
#                     52.02,
#                     12.1108
#                 ],
#                 [
#                     50.97,
#                     9.7705
#                 ],
#                 [
#                     62.34,
#                     11.2128
#                 ],
#                 [
#                     52.04,
#                     12.1061
#                 ],
#                 [
#                     80.19,
#                     10.4752
#                 ],
#                 [
#                     64.08,
#                     8.5831
#                 ],
#                 [
#                     48.79,
#                     11.8467
#                 ],
#                 [
#                     40.98,
#                     14.2753
#                 ],
#                 [
#                     70.39,
#                     12.2887
#                 ],
#                 [
#                     70.51,
#                     11.4878
#                 ],
#                 [
#                     89.49,
#                     9.9229
#                 ],
#                 [
#                     66.1,
#                     9.7882
#                 ],
#                 [
#                     66.31,
#                     11.6423
#                 ],
#                 [
#                     91.25,
#                     10.7398
#                 ],
#                 [
#                     76.36,
#                     11.2101
#                 ],
#                 [
#                     60.25,
#                     10.9212
#                 ],
#                 [
#                     68.26,
#                     9.3174
#                 ],
#                 [
#                     86.07,
#                     8.7139
#                 ],
#                 [
#                     73.59,
#                     10.5993
#                 ],
#                 [
#                     84.18,
#                     8.2918
#                 ],
#                 [
#                     50.19,
#                     11.2573
#                 ],
#                 [
#                     93.98,
#                     12.2367
#                 ],
#                 [
#                     72.91,
#                     7.3241
#                 ],
#                 [
#                     50.98,
#                     9.4155
#                 ],
#                 [
#                     60.06,
#                     10.8226
#                 ],
#                 [
#                     74.78,
#                     11.233
#                 ],
#                 [
#                     217.56,
#                     12.6402
#                 ],
#                 [
#                     145.85,

# %% [markdown]
# # 3.北京二手房房价预测

# %% [markdown]
# ## - 将除面积之外的其他属性，如所在区、户型等类别属性进行编码；并划分训练集和验证集。

# %%
from sklearn import preprocessing
from sklearn.model_selection import train_test_split

le = preprocessing.LabelEncoder()

X1 = le.fit(data['所在区'].unique()).transform(data['所在区'])  #X1表示房屋所在区
X2 = le.fit(data['户型'].unique()).transform(data['户型'])  #X2表示房屋的户型
X3 = data['面积(平米)']  #X3表示房屋的面积
X4 = le.fit(data['装修'].unique()).transform(data['装修'])  #X4表示房屋的装修
X5 = le.fit(data['有无电梯'].unique()).transform(data['有无电梯'])  #X5表示房屋有无电梯
X6 = le.fit(data['小区名称'].unique()).transform(data['小区名称'])  #X5表示房屋所在小区
X7 = le.fit(data['所在位置'].unique()).transform(data['所在位置'])  #X5表示房屋所在位置

X = np.mat([X1, X2, X3, X4, X5, X6, X7]).T
Y = data['单价(元/平米)']
print(np.array(X).shape)

#划分训练集和验证集
X_train, X_test, Y_train, Y_test = train_test_split(X,
                                                    Y,
                                                    test_size=0.1,
                                                    random_state=0)
print(X_train.shape, Y_train.shape)
print(X_test.shape, Y_test.shape)
# Out:
# (8418, 7)
# (7576, 7) (7576,)
# (842, 7) (842,)

# %% [markdown]
# ## 利用RandomizedSearchCV进行模型调参

# %%
#随机森林模型调参
##参数选择
from sklearn.model_selection import RandomizedSearchCV
from sklearn.ensemble import RandomForestRegressor

criterion = ['mse', 'mae']
n_estimators = [int(x) for x in np.linspace(start=200, stop=1200, num=50)]
max_features = ['auto', 'sqrt']
max_depth = [int(x) for x in np.linspace(10, 100, num=10)]
max_depth.append(None)
min_samples_split = [2, 5, 10]
min_samples_leaf = [1, 2, 4]
bootstrap = [True, False]
random_grid = {
    'criterion': criterion,
    'n_estimators': n_estimators,
    'max_features': max_features,
    'max_depth': max_depth,
    'min_samples_split': min_samples_split,
    'min_samples_leaf': min_samples_leaf,
    'bootstrap': bootstrap
}
#构建模型
clf = RandomForestRegressor()
clf_random = RandomizedSearchCV(estimator=clf,
                                param_distributions=random_grid,
                                n_iter=10,
                                cv=3,
                                verbose=2,
                                random_state=42,
                                n_jobs=10)
#回归
clf_random.fit(X_train, Y_train)
print(clf_random.best_params_)
# Out:
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# [Parallel(n_jobs=10)]: Using backend LokyBackend with 10 concurrent workers.
# [Parallel(n_jobs=10)]: Done  27 out of  30 | elapsed:  3.6min remaining:   23.8s
# [Parallel(n_jobs=10)]: Done  30 out of  30 | elapsed: 11.8min finished
# {'n_estimators': 1118, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 'sqrt', 'max_depth': 70, 'criterion': 'mae', 'bootstrap': True}

# %% [markdown]
# ## 模型训练及评估

# %%
##构建随机森林模型
##模型训练、验证、评估
from sklearn.ensemble import RandomForestRegressor
from pyecharts import Bar

#{'n_estimators': 506, 'min_samples_split': 10, 'min_samples_leaf': 4, 'max_features': 'sqrt', 'max_depth': 70, 'criterion': 'mse', 'bootstrap': True}
rf = RandomForestRegressor(criterion='mse',
                           bootstrap=True,
                           max_features='sqrt',
                           max_depth=70,
                           min_samples_split=10,
                           n_estimators=506,
                           min_samples_leaf=4)

rf.fit(X_train, Y_train)
Y_train_pred = rf.predict(X_train)
Y_test_pred = rf.predict(X_test)
#变量重要性
print("变量重要性：", rf.feature_importances_)
feature = ['所在区', '户型', '面积', '装修', '有无电梯', '小区名称', '所在位置']
bar = Bar()
bar.add('指标重要性',
        feature,
        rf.feature_importances_.round(2),
        is_label_show=True,
        label_text_color='#000')
bar.render('指标重要性.html')
bar
# Out:
# 变量重要性： [0.56431002 0.02732864 0.10233487 0.01361559 0.01910392 0.07470644
#  0.19860051]
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="465af47460884f8d8e9c70f6b5db0443" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_465af47460884f8d8e9c70f6b5db0443 = echarts.init(document.getElementById('465af47460884f8d8e9c70f6b5db0443'), 'light', {renderer: 'canvas'});
#
# var option_465af47460884f8d8e9c70f6b5db0443 = {
#     "title": [
#         {
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "\u4e0b\u8f7d\u56fe\u7247"
#             },
#             "restore": {
#                 "show": true
#             },
#             "dataView": {
#                 "show": true
#             }
#         }
#     },
#     "series_id": 1459602,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u6307\u6807\u91cd\u8981\u6027",
#             "data": [
#                 0.56,
#                 0.03,
#                 0.1,
#                 0.01,
#                 0.02,
#                 0.07,
#                 0.2
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "normal": {
#                     "show": true,
#                     "position": "top",
#                     "textStyle": {
#                         "color": "#000",
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "markLine": {
#                 "data": []
#             },
#             "seriesId": 1459602
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u6307\u6807\u91cd\u8981\u6027"
#             ],
#             "selectedMode": "multiple",
#             "show": true,
#             "left": "center",
#             "top": "top",
#             "orient": "horizontal",
#             "textStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "xAxis": [
#         {
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "boundaryGap": true,
#             "type": "category",
#             "splitLine": {
#                 "show": false
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "rotate": 0,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 12
#                 }
#             },
#             "data": [
#                 "\u6240\u5728\u533a",
#                 "\u6237\u578b",
#                 "\u9762\u79ef",
#                 "\u88c5\u4fee",
#                 "\u6709\u65e0\u7535\u68af",
#                 "\u5c0f\u533a\u540d\u79f0",
#                 "\u6240\u5728\u4f4d\u7f6e"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "boundaryGap": true,
#             "type": "value",
#             "splitLine": {
#                 "show": true
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "formatter": "{value} ",
#                 "rotate": 0,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 12
#                 }
#             }
#         }
#     ],
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ]
# };
# myChart_465af47460884f8d8e9c70f6b5db0443.setOption(option_465af47460884f8d8e9c70f6b5db0443);
#
#     });
# </script>

# %%
#模型评估
from sklearn.metrics import mean_squared_error, explained_variance_score, mean_absolute_error, r2_score
print("决策树模型评估--训练集：")
print('训练r^2:', rf.score(X_train, Y_train))
print('均方差', mean_squared_error(Y_train, Y_train_pred))
print('绝对差', mean_absolute_error(Y_train, Y_train_pred))
print('解释度', explained_variance_score(Y_train, Y_train_pred))

print("决策树模型评估--验证集：")
print('验证r^2:', rf.score(X_test, Y_test))
print('均方差', mean_squared_error(Y_test, Y_test_pred))
print('绝对差', mean_absolute_error(Y_test, Y_test_pred))
# Out:
# 决策树模型评估--训练集：
# 训练r^2: 0.8964673403834912
# 均方差 115335301.96236002
# 绝对差 7317.426608781318
# 解释度 0.8964673730463697
# 决策树模型评估--验证集：
# 验证r^2: 0.8195673521223061
# 均方差 202277553.95551667
# 绝对差 9542.345562101254

# %% [markdown]
# ## 房价预测

# %%
from sklearn import preprocessing

data_pre = pd.read_csv('house_bj_new.csv')
data_pre.head()
# Out:
#    所在区       小区名称    户型  面积(平米)  朝向  装修       所在楼层   建造年份  所在位置  总价(万元)  \
# 0  东城区  和平里中街3号院   2室1厅   77.73  东南  精装  高楼层(共20层)  2007年   和平里     959
# 1  东城区       忠实里   2室1厅   67.95  东南  简装  中楼层(共16层)  1980年   广渠门     705
# 2  东城区      竹杆胡同   2室1厅   68.25  南北  精装   中楼层(共6层)  2005年  朝阳门内     820
# 3  东城区    新景家园西区   1室1厅   59.18   南  简装  高楼层(共14层)  2004年   崇文门     712
# 4  东城区      水上华城   1室1厅   66.10  西南  简装  高楼层(共23层)  2006年   广渠门     850
#
#    单价(元/平米) 有无电梯
# 0    123376  有电梯
# 1    103753  有电梯
# 2    120147  无电梯
# 3    120311  有电梯
# 4    128594  有电梯

# %%
##对类别属性进行编码
le = preprocessing.LabelEncoder()

x1 = le.fit(data_pre['所在区'].unique()).transform(data_pre['所在区'])  #X1表示房屋所在区
x2 = le.fit(data_pre['户型'].unique()).transform(data_pre['户型'])  #X2表示房屋的户型
x3 = data_pre['面积(平米)']  #X3表示房屋的面积
x4 = le.fit(data_pre['装修'].unique()).transform(data_pre['装修'])  #X4表示房屋的装修
x5 = le.fit(data_pre['有无电梯'].unique()).transform(data_pre['有无电梯'])  #X5表示房屋有无电梯
x6 = le.fit(data_pre['小区名称'].unique()).transform(data_pre['小区名称'])  #X5表示房屋所在小区
x7 = le.fit(data_pre['所在位置'].unique()).transform(data_pre['所在位置'])  #X5表示房屋所在位置

x = np.mat([x1, x2, x3, x4, x5, x6, x7]).T
print(np.array(x).shape)

#对房价进行预测并保存到house_pre.csv文件中
y_pred = rf.predict(x)
print('######')
result = pd.DataFrame()
result['所在区'] = data_pre['所在区']
result['小区名称'] = data_pre['小区名称']
result['所在位置'] = data_pre['所在位置']
result['真实值'] = data_pre['单价(元/平米)']
result['预测值'] = y_pred.round(2)
result.head()
result.to_csv("house_pre.csv")
# Out:
# (1100, 7)
# ######

# %% [markdown]
# ## 可视化预测的房价

# %%
##调用百度地图，获取每个位置经纬度
# -*- coding: utf-8 -*-
import json
from urllib.request import urlopen, quote
import pandas as pd
import numpy as np

ak = 'z3YjMSWj2eZhsopS7uoP6Qn9zw0CvHR5'  # ak是申请的调用百度地图的key值


##根据地址名称获取经纬度函数
def getlnglat(address):
    url = 'http://api.map.baidu.com/geocoder/v2/'
    output = 'json'
    add = quote(address)  #由于本文城市变量为中文，为防止乱码，先用quote进行编码
    uri = url + '?' + 'address=' + add + '&output=' + output + '&ak=' + ak
    req = urlopen(uri)
    res = req.read().decode()  #将其他编码的字符串解码成unicode
    temp = json.loads(res)  #对json数据进行解析
    return temp


data = pd.read_csv('house_pre.csv')
print(data.head())

#将预测值按小区名称分组统计
df = data.groupby(['所在位置', '所在区'])['真实值', '预测值'].mean().round(2).reset_index()
add = []
for i in range(len(df)):
    df.iloc[i, 0]
    add.append('北京市' + df.iloc[i, 1] + df.iloc[i, 0])
df['地址'] = add

lat = []
lng = []
for addr in df[u'地址'].values:
    res = getlnglat(addr)
    lat.append(res['result']['location']['lat'])
    lng.append(res['result']['location']['lng'])
df[u'维度'] = lat
df[u'经度'] = lng
print(df.head())
df.to_csv('house_add.csv', index=False)
df.head()
# Out:
#    Unnamed: 0  所在区       小区名称  所在位置     真实值        预测值
# 0           0  东城区  和平里中街3号院    和平里  123376   99680.55
# 1           1  东城区       忠实里    广渠门  103753  102533.44
# 2           2  东城区      竹杆胡同   朝阳门内  120147  104050.60
# 3           3  东城区    新景家园西区    崇文门  120311  101143.00
# 4           4  东城区      水上华城    广渠门  128594   99795.06
# <ipython-input-33-e37aa439cc35>:27: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df = data.groupby(['所在位置', '所在区'])['真实值', '预测值'].mean().round(2).reset_index()
#   所在位置  所在区        真实值       预测值         地址         维度          经度
# 0  七里庄  丰台区   65124.57  58708.40  北京市丰台区七里庄  39.870409  116.296380
# 1   万柳  海淀区  153240.33  91216.27   北京市海淀区万柳  39.977845  116.302908
# 2   万源  大兴区   39216.00  57175.67   北京市大兴区万源  39.732555  116.348625
# 3   万达  通州区   42766.50  51531.49   北京市通州区万达  39.911427  116.648130
# 4  三元桥  朝阳区  120721.00  84599.56  北京市朝阳区三元桥  39.962914  116.458335
#   所在位置  所在区        真实值       预测值         地址         维度          经度
# 0  七里庄  丰台区   65124.57  58708.40  北京市丰台区七里庄  39.870409  116.296380
# 1   万柳  海淀区  153240.33  91216.27   北京市海淀区万柳  39.977845  116.302908
# 2   万源  大兴区   39216.00  57175.67   北京市大兴区万源  39.732555  116.348625
# 3   万达  通州区   42766.50  51531.49   北京市通州区万达  39.911427  116.648130
# 4  三元桥  朝阳区  120721.00  84599.56  北京市朝阳区三元桥  39.962914  116.458335

# %%
from pyecharts import Geo
import pandas as pd

df = pd.read_csv('house_add.csv')

geo_cities_coords = {
    df.iloc[i]['地址']: [df.iloc[i]['经度'], df.iloc[i]['维度']]
    for i in range(len(df))
}
attr = list(df['地址'])
value = list(df['预测值'])

geo = Geo("北京市各区二手房房价量",
          "预测值",
          title_color="#fff",
          title_pos="left",
          width=1000,
          height=600,
          background_color='#404a59')

##自定义坐标点
for i in range(len(df)):
    geo.add_coordinate(df.iloc[i]['地址'], df.iloc[i]['经度'], df.iloc[i]['维度'])

geo.add("",
        attr,
        value,
        maptype='北京',
        visual_range=[min(value), max(value)],
        visual_text_color="#fff",
        symbol_size=15,
        is_visualmap=True,
        is_geo_effect_show=True,
        type='effectScatter',
        border_color='#eef')
geo  #直接在notebook中显示
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min', 'beijing': '/nbextensions/echarts-china-cities-js/beijing'
#         }
#     });
# </script>
#     <div id="20fae0a04a1b40398f854d90aa4cedba" style="width:1000px;height:600px;"></div>
#
#
# <script>
#     require(['echarts', 'beijing'], function(echarts) {
#
# var myChart_20fae0a04a1b40398f854d90aa4cedba = echarts.init(document.getElementById('20fae0a04a1b40398f854d90aa4cedba'), 'light', {renderer: 'canvas'});
#
# var option_20fae0a04a1b40398f854d90aa4cedba = {
#     "title": [
#         {
#             "text": "\u5317\u4eac\u5e02\u5404\u533a\u4e8c\u624b\u623f\u623f\u4ef7\u91cf",
#             "subtext": "\u9884\u6d4b\u503c",
#             "left": "left",
#             "top": "auto",
#             "textStyle": {
#                 "color": "#fff",
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "\u4e0b\u8f7d\u56fe\u7247"
#             },
#             "restore": {
#                 "show": true
#             },
#             "dataView": {
#                 "show": true
#             }
#         }
#     },
#     "series_id": 2811875,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "formatter": "{b}: {c}",
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "effectScatter",
#             "coordinateSystem": "geo",
#             "showEffectOn": "render",
#             "rippleEffect": {
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             },
#             "symbol": "circle",
#             "symbolSize": 15,
#             "data": [
#                 {
#                     "name": "\u5317\u4eac\u5e02\u4e30\u53f0\u533a\u4e03\u91cc\u5e84",
#                     "value": [
#                         116.29638003326232,
#                         39.87040909065006,
#                         58708.4
#                     ]
#                 },
#                 {
#                     "name": "\u5317\u4eac\u5e02\u6d77\u6dc0\u533a\u4e07\u67f3",
#                     "value": [
#                         116.302908288895,
#                         39.977844594434,
#                         91216.27
#                     ]
#                 },
#                 {
#                     "name": "\u5317\u4eac\u5e02\u5927\u5174\u533a\u4e07\u6e90",
#                     "value": [
#                         116.348625212231,
#                         39.73255523655448,
#                         57175.67
#                     ]
#                 },
#                 {
#                     "name": "\u5317\u4eac\u5e02\u901a\u5dde\u533a\u4e07\u8fbe",
#                     "value": [
#                         116.64812979129604,
#                         39.91142679333696,
#                         51531.49
#                     ]
#                 },
#                 {
#                     "name": "\u5317\u4eac\u5e02\u671d\u9633\u533a\u4e09\u5143\u6865",
#                     "value": [
#                         116.45833517433404,
#                         39.96291393417554,
#                         84599.56
#                     ]
#                 },
#                 {
#                     "name": "\u5317\u4eac\u5e02\u6d77\u6dc0\u533a\u4e0a\u5730",
#                     "value": [
#                         116.30166880695232,
#                         40.048557259563566,
#                         88245.94
#                     ]
#                 },
#                 {
#                     "name": "\u5317\u4eac\u5e02\u6d77\u6dc0\u533a\u4e16\u7eaa\u57ce",
#                     "value": [
#                         116.29050583387148,
#                         39.97144853209294,
#                         92718.24
#                     ]
#                 },
#                 {
#                     "name": "\u5317\u4eac\u5e02\u660c\u5e73\u533a\u4e1c\u5173",
#                     "value": [
#                         116.26416796547169,
#                         40.22744802301974,
#                         51694.43
#                     ]
#                 },
#                 {
#                     "name": "\u5317\u4eac\u5e02\u4e1c\u57ce\u533a\u4e1c\u56db",
#                     "value": [
#                         116.43056459847638,
#                         39.9363894150444,
#                         99970.55
#                     ]
#                 },
#                 {
#                     "name": "\u5317\u4eac\u5e02\u671d\u9633\u533a\u4e1c\u575d",
#                     "value": [
#                         116.55407540779034,
#                         39.9679048723638,
#                         69315.76
#                     ]
#                 },
#                 {
#                     "name": "\u5317\u4eac\u5e02\u671d\u9633\u533a\u4e1c\u5927\u6865",
#                     "value": [
#                         116.45853019646026,
#                         39.929006109102126,
#                         81284.42
#                     ]
#                 },
#                 {
#                     "name": "\u5317\u4eac\u5e02\u4e1c\u57ce\u533a\u4e1c\u76f4\u95e8",
#                     "value": [
#                         116.4483604797818,
#                         39.93665116326292,
#                         98364.42
#                     ]
#                 },
#                 {
#                     "name": "\u5317\u4eac\u5e02\u4e1c\u57ce\u533a\u4e1c\u82b1\u5e02",
#                     "value": [
#                         116.44020009286808,
#                         39.9033835617071,
#                         101073.84
#                     ]
#                 },
#                 {
#                     "name": "\u5317\u4eac\u5e02\u6d77\u6dc0\u533a\u4e2d\u5173\u6751",
#                     "value": [
#                         116.324956478993,
#                         39.98387690325234,
#                         85029.63
#                     ]
#                 },
#                 {
#                     "name": "\u5317\u4eac\u5e02\u4e30\u53f0\u533a\u4e30\u53f0\u5176\u5b83",
#                     "value": [
#                         116.2924018873114,
#                         39.8649371975573,
#                         62596.98
#                     ]
#                 },
#                 {
#                     "name": "\u5317\u4eac\u5e02\u901a\u5dde\u533a\u4e34\u6cb3\u91cc",
#                     "value": [
#                         116.69620395812078,
#                         39.87979008668561,
#                         49370.06
#                     ]
#                 },
#                 {
#                     "name": "\u5317\u4eac\u5e02\u4e30\u53f0\u533a\u4e3d\u6cfd",
#                     "value": [
#                         116.31582196958423,
#                         39.87831897320625,
#                         57506.0
#                     ]
#                 },
#                 {
#                     "name": "\u5317\u4eac\u5e02\u5927\u5174\u533a\u4e49\u548c\u5e84",
#                     "value": [
#                         116.33768888163031,
#                         39.72106684449399,
#                         47266.11
#                     ]
#                 },
#                 {
#                     "name": "\u5317\u4eac\u5e02\u901a\u5dde\u533a\u4e54\u5e84",
#                     "value": [
#                         116.6950528694403,
#                         39.903015550659696,
#                         51215.43
#                     ]
#                 },
#                 {
#                     "name": "\u5317\u4eac\u5e02\u901a\u5dde\u533a\u4e5d\u68f5\u6811(\u5bb6\u4e50\u798f)",
#                     "value": [
#                         116.6630938543118,
#                         39.89584243138125,
#                         47186.64
#                     ]
